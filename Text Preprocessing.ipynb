# %% [markdown]
# # Text Preprocessing:

# %%
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import ngrams
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
input_str = "John Wick (retrospectively known as John Wick: Chapter 1) is a 2014 American neo-noir action thriller film directed by Chad Stahelski and written by Derek Kolstad. It stars Keanu Reeves, Michael Nyqvist, Alfie Allen, Adrianne Palicki, Bridget Moynahan, Dean Winters, Ian McShane, John Leguizamo, and Willem Dafoe.It grossed $88 million worldwide against a production budget of $20 million."
input_str
# Out:
# 'John Wick (retrospectively known as John Wick: Chapter 1) is a 2014 American neo-noir action thriller film directed by Chad Stahelski and written by Derek Kolstad. It stars Keanu Reeves, Michael Nyqvist, Alfie Allen, Adrianne Palicki, Bridget Moynahan, Dean Winters, Ian McShane, John Leguizamo, and Willem Dafoe.It grossed $88 million worldwide against a production budget of $20 million.'

# %% [markdown]
# ### Convert text to lowercase

# %%
lower_str = input_str.lower()
lower_str
# Out:
# 'john wick (retrospectively known as john wick: chapter 1) is a 2014 american neo-noir action thriller film directed by chad stahelski and written by derek kolstad. it stars keanu reeves, michael nyqvist, alfie allen, adrianne palicki, bridget moynahan, dean winters, ian mcshane, john leguizamo, and willem dafoe.it grossed $88 million worldwide against a production budget of $20 million.'

# %% [markdown]
# ### Remove punctuation

# %%
punc_free = input_str.translate(str.maketrans('', '', string.punctuation))
punc_free
# Out:
# 'John Wick retrospectively known as John Wick Chapter 1 is a 2014 American neonoir action thriller film directed by Chad Stahelski and written by Derek Kolstad It stars Keanu Reeves Michael Nyqvist Alfie Allen Adrianne Palicki Bridget Moynahan Dean Winters Ian McShane John Leguizamo and Willem DafoeIt grossed 88 million worldwide against a production budget of 20 million'

# %% [markdown]
# ### Remove stop words

# %% [markdown]
# Remove stop words using Natural Language Toolkit (NLTK), a suite of libraries and programs for symbolic and statistical natural language  processing.

# %%
# setting stop words for English language
stop_words = set(stopwords.words('english'))

tokens = word_tokenize(punc_free)
result = [i for i in tokens if not i in stop_words]
result
# Out:
# ['John',
#  'Wick',
#  'retrospectively',
#  'known',
#  'John',
#  'Wick',
#  'Chapter',
#  '1',
#  '2014',
#  'American',
#  'neonoir',
#  'action',
#  'thriller',
#  'film',
#  'directed',
#  'Chad',
#  'Stahelski',
#  'written',
#  'Derek',
#  'Kolstad',
#  'It',
#  'stars',
#  'Keanu',
#  'Reeves',
#  'Michael',
#  'Nyqvist',
#  'Alfie',
#  'Allen',
#  'Adrianne',
#  'Palicki',
#  'Bridget',
#  'Moynahan',
#  'Dean',
#  'Winters',
#  'Ian',
#  'McShane',
#  'John',
#  'Leguizamo',
#  'Willem',
#  'DafoeIt',
#  'grossed',
#  '88',
#  'million',
#  'worldwide',
#  'production',
#  'budget',
#  '20',
#  'million']

# %% [markdown]
# ### Stemming

# %% [markdown]
#  Process of reducing words to their word stem, base or root form

# %%
stemmer = PorterStemmer()
stem_str = word_tokenize(punc_free)
for word in stem_str:
    print(stemmer.stem(word))
# Out:
# john
# wick
# retrospect
# known
# as
# john
# wick
# chapter
# 1
# is
# a
# 2014
# american
# neonoir
# action
# thriller
# film
# direct
# by
# chad
# stahelski
# and
# written
# by
# derek
# kolstad
# It
# star
# keanu
# reev
# michael
# nyqvist
# alfi
# allen
# adriann
# palicki
# bridget
# moynahan
# dean
# winter
# ian
# mcshane
# john
# leguizamo
# and
# willem
# dafoeit
# gross
# 88
# million
# worldwid
# against
# a
# product
# budget
# of
# 20
# million

# %% [markdown]
# ### Lemmatization

# %% [markdown]
# Uses lexical knowledge bases to get the correct base forms of words

# %%
lemmatizer = WordNetLemmatizer()
lemm_str = word_tokenize(punc_free)
for word in lemm_str:
    print(lemmatizer.lemmatize(word))
# Out:
# John
# Wick
# retrospectively
# known
# a
# John
# Wick
# Chapter
# 1
# is
# a
# 2014
# American
# neonoir
# action
# thriller
# film
# directed
# by
# Chad
# Stahelski
# and
# written
# by
# Derek
# Kolstad
# It
# star
# Keanu
# Reeves
# Michael
# Nyqvist
# Alfie
# Allen
# Adrianne
# Palicki
# Bridget
# Moynahan
# Dean
# Winters
# Ian
# McShane
# John
# Leguizamo
# and
# Willem
# DafoeIt
# grossed
# 88
# million
# worldwide
# against
# a
# production
# budget
# of
# 20
# million

# %% [markdown]
# ### Tokenization

# %% [markdown]
#  Process of splitting the given text into smaller pieces called tokens

# %%
tokens = word_tokenize(input_str)
tokens
# Out:
# ['John',
#  'Wick',
#  '(',
#  'retrospectively',
#  'known',
#  'as',
#  'John',
#  'Wick',
#  ':',
#  'Chapter',
#  '1',
#  ')',
#  'is',
#  'a',
#  '2014',
#  'American',
#  'neo-noir',
#  'action',
#  'thriller',
#  'film',
#  'directed',
#  'by',
#  'Chad',
#  'Stahelski',
#  'and',
#  'written',
#  'by',
#  'Derek',
#  'Kolstad',
#  '.',
#  'It',
#  'stars',
#  'Keanu',
#  'Reeves',
#  ',',
#  'Michael',
#  'Nyqvist',
#  ',',
#  'Alfie',
#  'Allen',
#  ',',
#  'Adrianne',
#  'Palicki',
#  ',',
#  'Bridget',
#  'Moynahan',
#  ',',
#  'Dean',
#  'Winters',
#  ',',
#  'Ian',
#  'McShane',
#  ',',
#  'John',
#  'Leguizamo',
#  ',',
#  'and',
#  'Willem',
#  'Dafoe.It',
#  'grossed',
#  '$',
#  '88',
#  'million',
#  'worldwide',
#  'against',
#  'a',
#  'production',
#  'budget',
#  'of',
#  '$',
#  '20',
#  'million',
#  '.']

# %% [markdown]
# ### N-grams

# %%
n = 3
three_grams = ngrams(lower_str.split(), n)

for grams in three_grams:
    print(grams)
# Out:
# ('john', 'wick', '(retrospectively')
# ('wick', '(retrospectively', 'known')
# ('(retrospectively', 'known', 'as')
# ('known', 'as', 'john')
# ('as', 'john', 'wick:')
# ('john', 'wick:', 'chapter')
# ('wick:', 'chapter', '1)')
# ('chapter', '1)', 'is')
# ('1)', 'is', 'a')
# ('is', 'a', '2014')
# ('a', '2014', 'american')
# ('2014', 'american', 'neo-noir')
# ('american', 'neo-noir', 'action')
# ('neo-noir', 'action', 'thriller')
# ('action', 'thriller', 'film')
# ('thriller', 'film', 'directed')
# ('film', 'directed', 'by')
# ('directed', 'by', 'chad')
# ('by', 'chad', 'stahelski')
# ('chad', 'stahelski', 'and')
# ('stahelski', 'and', 'written')
# ('and', 'written', 'by')
# ('written', 'by', 'derek')
# ('by', 'derek', 'kolstad.')
# ('derek', 'kolstad.', 'it')
# ('kolstad.', 'it', 'stars')
# ('it', 'stars', 'keanu')
# ('stars', 'keanu', 'reeves,')
# ('keanu', 'reeves,', 'michael')
# ('reeves,', 'michael', 'nyqvist,')
# ('michael', 'nyqvist,', 'alfie')
# ('nyqvist,', 'alfie', 'allen,')
# ('alfie', 'allen,', 'adrianne')
# ('allen,', 'adrianne', 'palicki,')
# ('adrianne', 'palicki,', 'bridget')
# ('palicki,', 'bridget', 'moynahan,')
# ('bridget', 'moynahan,', 'dean')
# ('moynahan,', 'dean', 'winters,')
# ('dean', 'winters,', 'ian')
# ('winters,', 'ian', 'mcshane,')
# ('ian', 'mcshane,', 'john')
# ('mcshane,', 'john', 'leguizamo,')
# ('john', 'leguizamo,', 'and')
# ('leguizamo,', 'and', 'willem')
# ('and', 'willem', 'dafoe.it')
# ('willem', 'dafoe.it', 'grossed')
# ('dafoe.it', 'grossed', '$88')
# ('grossed', '$88', 'million')
# ('$88', 'million', 'worldwide')
# ('million', 'worldwide', 'against')
# ('worldwide', 'against', 'a')
# ('against', 'a', 'production')
# ('a', 'production', 'budget')
# ('production', 'budget', 'of')
# ('budget', 'of', '$20')
# ('of', '$20', 'million.')

# %% [markdown]
# ### Document term matrix representation

# %%
docs =["john wick (retrospectively known as john wick: chapter 1) is a 2014 american neo-noir action thriller film directed by chad stahelski and written by derek kolstad",
       "it stars keanu reeves, michael nyqvist, alfie allen, adrianne palicki, bridget moynahan, dean winters, ian mcshane, john leguizamo, and willem dafoe" ,
       "it grossed $88 million worldwide against a production budget of $20 million"]
vec = CountVectorizer()
X = vec.fit_transform(docs)

df = pd.DataFrame(X.toarray(), columns=vec.get_feature_names())
df
# Out:
#    20  2014  88  action   ...     willem  winters  worldwide  written
# 0   0     1   0       1   ...          0        0          0        1
# 1   0     0   0       0   ...          1        1          0        0
# 2   1     0   1       0   ...          0        0          1        0
#
# [3 rows x 50 columns]

# %% [markdown]
# ### TF-IDF

# %%
docs =["john wick (retrospectively known as john wick: chapter 1) is a 2014 american neo-noir action thriller film directed by chad stahelski and written by derek kolstad",
       "it stars keanu reeves, michael nyqvist, alfie allen, adrianne palicki, bridget moynahan, dean winters, ian mcshane, john leguizamo, and willem dafoe" ,
       "it grossed $88 million worldwide against a production budget of $20 million"]

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(docs)

df = pd.DataFrame(X.toarray(), columns=vec.get_feature_names())
df
# Out:
#         20      2014       88    ...      winters  worldwide   written
# 0  0.00000  0.186042  0.00000    ...     0.000000    0.00000  0.186042
# 1  0.00000  0.000000  0.00000    ...     0.225102    0.00000  0.000000
# 2  0.28196  0.000000  0.28196    ...     0.000000    0.28196  0.000000
#
# [3 rows x 50 columns]
